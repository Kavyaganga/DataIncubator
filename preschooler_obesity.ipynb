# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
health_sheet = 'HEALTH'
health_data = pd.read_excel("DataDownload.xls", sheet_name=health_sheet)
fig = plt.figure(figsize=(30,10))
plt.stem(health_data['State'],health_data['PCH_OBESE_CHILD_08_11'])
plt.ylabel('obesity rate')
plt.title('Preschool obesity rate change between 2008 - 2011')
plt.show()
# Out:
# <function matplotlib.pyplot.show>
